# %% [markdown]
# lecture  10: MACHINE LEARNING II

# %%
import numpy as np
import sklearn.linear_model as skmod
import matplotlib.pyplot as plt

# %%
alt = [3.25, 0.816, 4.376, 1314, 3.982, 2.957, 2.482]
np_goaters = [2.45, 5.45, 4.13156, 0.1546, 2.54, 1.64, 3.5464]


arr_x = np.array(alt)
arr_x = arr_x.reshape(-1,1)
print(arr_x)

arr_y =  np.array(np_goaters)
arr_y = arr_y.reshape(-1,1)
print(arr_y)
# Out:
# [[3.250e+00]
#  [8.160e-01]
#  [4.376e+00]
#  [1.314e+03]
#  [3.982e+00]
#  [2.957e+00]
#  [2.482e+00]]
# [[2.45   ]
#  [5.45   ]
#  [4.13156]
#  [0.1546 ]
#  [2.54   ]
#  [1.64   ]
#  [3.5464 ]]

# %%
plt.plot(arr_x, arr_y)

# %%
model = skmod.LinearRegression()

# %%
model_trained = model.fit(arr_x, arr_y)

# %%
print(model_trained.coef_)
print(model_trained.intercept_)

print(model_trained.score(arr_x, arr_y))
# Out:
# [[-0.00239694]]
# [3.30070764]
# 0.47359080548719457

# %%
plt.scatter(arr_x, arr_y)
plt.plot([0,5] ,[-1.83 * 0 + 26.6, -1.83 * 5 + 26.6])

# %%
x_for_predict = np.array([[0], [2.5], [5]])
print(x_for_predict)
print(model.predict(x_for_predict))
# Out:
# [[0. ]
#  [2.5]
#  [5. ]]
# [[3.30070764]
#  [3.29471529]
#  [3.28872294]]

# %%
print(model.coef_[0] * 2.5 + model.intercept_)
# Out:
# [3.29471529]

# %%
feature = [25, 100, 30, 5, 85]
label = [80, 254, 152, 4, 271]


ar_x = np.array(feature)
ar_x = ar_x.reshape(-1,1)
ar_y = np.array(label)
ar_y = ar_y.reshape(-1,1)

# %%
plt.scatter(ar_x, ar_y )

# %%
model = skmod.LinearRegression()

# %%
model_trained = model.fit(ar_x, ar_y)

# %%
print(model_trained.coef_[0][0])
print(model_trained.intercept_[0])
# Out:
# 2.6183161004431312
# 23.90251107828655

# %%
plt.scatter(ar_x, ar_y )
plt.plot([0,100], [2.61 * 0 + 23.9, 2.61 * 100 + 23.9 ])

# %%
feature = [13,3, 17,0, 2]
label = [505, 35, 836, -6, 16]

# feature2 = []
# for i in feature:
#     feature2.append(i**2)

arr_x1 = np.array(feature).reshape(-1,1)
# arr_x2 = np.array(feature2).reshape(-1,1)
arr_x2 = arr_x1 * arr_x1


# print(arr_x1)
# print(arr_x2)
arr_x = np.hstack([arr_x1, arr_x2])
arr_y = np.array(label).reshape(-1,1)
print(arr_x)
# Out:
# [[ 13 169]
#  [  3   9]
#  [ 17 289]
#  [  0   0]
#  [  2   4]]

# %%
model = skmod.LinearRegression().fit(arr_x, arr_y)
print(model.coef_)
print(model.intercept_)

# equation y' = 6.05 * x + 2,56 * x^2 -6.15

print(model.score(arr_x, arr_y))
# Out:
# [[6.05253902 2.55824485]]
# [-6.15443798]
# 0.9999998602607547

# %%
plt.scatter(arr_x, arr_y)
x_for_plot = np.arange(0,17,0.1) 
x2_for_plot = x_for_plot*x_for_plot
x_final = np.hstack([x_for_plot.reshape(-1,1),x2_for_plot.reshape(-1,1) ])
y_for_plot = model.predict(x_final)
plt.plot(x_for_plot, y_for_plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\USER\Desktop\ICT\code\lection\lec10\1.ipynb Ячейка 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/ICT/code/lection/lec10/1.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> plt.scatter(arr_x, arr_y)
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/ICT/code/lection/lec10/1.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> x_for_plot = np.arange(0,17,0.1)
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Desktop/ICT/code/lection/lec10/1.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a> x2_for_plot = x_for_plot*x_for_plot
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2778, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2773 @_copy_docstring_and_deprecators(Axes.scatter)
# ...
