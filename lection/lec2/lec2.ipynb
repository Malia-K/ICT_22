# %%
# "r" - reading
# "w" - writing
# "a" - append (writing)


import csv
print(r"C:\Users\USER\Desktop\ICT\code\prac1\CSCO.csv")

file = open(r"C:\Users\USER\Desktop\ICT\code\lection\lec2\CSCO.csv", "r")
# Out:
# C:\Users\USER\Desktop\ICT\code\prac1\CSCO.csv
# <_io.TextIOWrapper name='C:\\Users\\USER\\Desktop\\ICT\\code\\lection\\lec2\\CSCO.csv' mode='r' encoding='cp1251'>

# %%
import csv
with open(r"C:\Users\USER\Desktop\ICT\code\lection\lec2\CSCO.csv", "r") as file:
    csvfile = csv.reader(file)
    csvfile.__next__(); # go to next row

    for row in csvfile:
        print(row)
        break
# Out:
# ['1990-02-16', '0.000000', '0.079861', '0.073785', '0.077257', '0.055372', '940636800']

# %%
import csv
with open(r"C:\Users\USER\Desktop\ICT\code\lection\lec2\CSCO.csv", "r") as file:
    csvfile = csv.DictReader(file)
   
    for row in csvfile:
        print(row)
# Out:
# {'Date': '1990-02-16', 'Open': '0.000000', 'High': '0.079861', 'Low': '0.073785', 'Close': '0.077257', 'Adj Close': '0.055372', 'Volume': '940636800'}
# {'Date': '1990-02-20', 'Open': '0.000000', 'High': '0.079861', 'Low': '0.074653', 'Close': '0.079861', 'Adj Close': '0.057238', 'Volume': '151862400'}
# {'Date': '1990-02-21', 'Open': '0.000000', 'High': '0.078993', 'Low': '0.075521', 'Close': '0.078125', 'Adj Close': '0.055994', 'Volume': '70531200'}
# {'Date': '1990-02-22', 'Open': '0.000000', 'High': '0.081597', 'Low': '0.078993', 'Close': '0.078993', 'Adj Close': '0.056616', 'Volume': '45216000'}
# {'Date': '1990-02-23', 'Open': '0.000000', 'High': '0.079861', 'Low': '0.078125', 'Close': '0.078559', 'Adj Close': '0.056305', 'Volume': '44697600'}
# {'Date': '1990-02-26', 'Open': '0.000000', 'High': '0.079861', 'Low': '0.076389', 'Close': '0.076389', 'Adj Close': '0.054750', 'Volume': '26928000'}
# ...

# %%
a = [564, 166, 12]
for index, item in enumerate(a): 
    print(index)
    print(item)
# Out:
# 0
# 564
# 1
# 166
# 2
# 12

# %% [markdown]
# Get csv data into py console

# %%
info = [1, 2, 3]
info2 = info #wrong
#info2 = (info2.append(i) for i in info)
info2.append(7)
print(info, info2)
# Out:
# [1, 2, 3, 7] [1, 2, 3, 7]

# %%
#task 5 from pr 1
import csv

l1, l2, l3 = [], [], []

with open(r"C:\Users\USER\Desktop\ICT\code\prac1\CSCO.csv", "r") as file:
    csvfile = csv.reader(file)
    csvfile.__next__()
    for row in csvfile:
        l1.append(row[0])
        l2.append(row[1])
        l3.append(row[2])

print(l1[:10])
print(l2[:10])
print(l3[:10])
# Out:
# ['1990-02-16', '1990-02-20', '1990-02-21', '1990-02-22', '1990-02-23', '1990-02-26', '1990-02-27', '1990-02-28', '1990-03-01', '1990-03-02']
# ['0.000000', '0.000000', '0.000000', '0.000000', '0.000000', '0.000000', '0.000000', '0.000000', '0.000000', '0.000000']
# ['0.079861', '0.079861', '0.078993', '0.081597', '0.079861', '0.079861', '0.079427', '0.082465', '0.081597', '0.081597']

# %%
lists = ([] for i in range(7))


with open(r"C:\Users\USER\Desktop\ICT\code\prac1\CSCO.csv", "r") as file:
    csvfile = csv.reader(file)
    csvfile.__next__()
    for row in csvfile:
        for index, l in enumerate(lists):
            l.append(row[index])
        for index in range(0, len(lists)):
            l.append(row[index])

# %%
#task 6 from pr 1
#MODIFY DATA
import csv
import datetime

l1, l2, l3 = [], [], []

with open(r"C:\Users\USER\Desktop\ICT\code\prac1\CSCO.csv", "r") as file:
    csvfile = csv.reader(file)
    csvfile.__next__()
    for row in csvfile:
        l1.append(row[0])
        l2.append(row[1])
        l3.append(row[2])

# print(l1[:10])
# print(l2[:10])
# print(l3[:10])

# turn into float

# for i in range(1, len(l2)):
#     l2[i] = (float(j) for j in l2[i])

# print(l2[1][0])


# turn into datetime
print(type(datetime.datetime.strptime("1962-01-02", "%Y-%m-%d" )))
# Out:
# <class 'datetime.datetime'>
