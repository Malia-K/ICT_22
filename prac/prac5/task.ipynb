# %%
import requests
import pandas as pd
import io

# 1ST COMPANY - CISCO
url_csco = "https://query1.finance.yahoo.com/v7/finance/download/CSCO?period1=1633475167&period2=1665011167&interval=1d&events=history&includeAdjustedClose=true"

headers = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}


## with human choice

# print("Enter the company name(esc for exit): ")
# comp = input()

# url = "https://query1.finance.yahoo.com/v7/finance/download/" + comp + "?period1=1633475167&period2=1665011167&interval=1d&events=history&includeAdjustedClose=true"
# resp = requests.get(url, headers=headers)
# df = pd.read_csv(io.StringIO(resp.content.decode('utf-8')))
# print(df)






## with loop

companies = ["CSCO", "AAPL", "SBUX"]

for i in companies:
    url = "https://query1.finance.yahoo.com/v7/finance/download/" + i + "?period1=1633475167&period2=1665011167&interval=1d&events=history&includeAdjustedClose=true"
    resp = requests.get(url, headers=headers)

    df = pd.read_csv(io.StringIO(resp.content.decode('utf-8')))
    print("=========== "+ i + " ===========" )
    print(df)
# Out:
# =========== CSCO ===========
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2021-10-05  54.130001  55.029999  54.130001  54.689999  53.025593
# 1    2021-10-06  54.349998  54.380001  52.980000  53.939999  52.298424
# 2    2021-10-07  54.490002  55.410000  54.349998  55.020000  53.345558
# 3    2021-10-08  55.200001  55.299999  54.750000  55.080002  53.403728
# 4    2021-10-11  55.250000  55.380001  54.900002  54.930000  53.258297
# ..          ...        ...        ...        ...        ...        ...
# 248  2022-09-29  41.049999  41.099998  40.150002  40.570000  40.196625
# 249  2022-09-30  40.660000  41.040001  39.959999  40.000000  39.631874
# 250  2022-10-03  40.669998  41.529999  40.470001  41.290001  40.910000
# 251  2022-10-04  41.560001  42.040001  41.389999  41.820000  41.820000
# 252  2022-10-05  41.590000  42.250000  41.400002  41.990002  41.990002
#
#        Volume
# 0    14135000
# 1    26339200
# 2    14725500
# 3     9255500
# ...
